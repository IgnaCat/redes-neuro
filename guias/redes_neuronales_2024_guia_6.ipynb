# %% [markdown]
# # Caos I: la ecuación de Lorenz
#
# ## **Ejercicio 1)** Importando librerías
#
# **1)** Importe las librerías `numpy` para operar con arrays, `scipy.signal` para analizar señales de datos y `matplotlib.pyplot` para graficar.
#
# **2)** Suba el archivo "libreria" `ode.py` que fabricó en el práctico 4), e impórtelo.

# %%
# a)
import numpy as np
#import scipy as sp
import scipy.signal as sgn
#import scipy.linalg as linalg
import matplotlib.pyplot as plt

# %%
# b)
#import ode

def euler(f,x,t,h,p):
    """
    Calcula un paso de integración del método de Euler.

    Argumentos de entrada:

        f : R^n,R -> R^n
        x = x(t) : R^n
        t = tiempo : R
        h = paso de tiempo : R
        p = parametros : R^q

    Retorna aproximacion numérica de

        x(t+h) : R^n

    según el método de Euler.

    # Ejemplos:
    """
    return x+h*f(x,t,p)

def rk4(f,x,t,h,p):
    """
    Calcula un paso de integración del método de Runge Kutta orden 4.

    Argumentos de entrada:

        f : R^n -> R^n
        x = x(t) : R^n
        t = tiempo : R
        h = paso de tiempo : R
        p = parametros : R^q

    Retorna aproximacion numérica de

        x(t+h) : R^n

    según el método de Runge-Kutta de orden 4.

    # Ejemplos:
    """
    k1 = f(x,t,p)
    k2 = f(x+0.5*h*k1,t+0.5*h,p)
    k3 = f(x+0.5*h*k2,t+0.5*h,p)
    k4 = f(x+h*k3,t+h,p)
    return x+h*(k1+2.0*k2+2.0*k3+k4)/6.0

def integrador_ode(m,f,xa,a,b,k,p,c=lambda x,t,p:x):
    """
    Integra numéricamente la ODE

        dx/dt = f(x,t)

    sobre el intervalo t:[a,b] usando k pasos de integración y el método m, bajo condicion inicial x(a)=x0.
    No es necesario que a<b.

    Argumentos de entrada:

        m = metodo de integracion (ej. euler, rk2, etc.)
        f : R^n -> R^n
        xa = condicion inicial : R
        a = tiempo inicial : R
        b = tiempo final : R
        k = num. pasos de integracion : N
        p = parametros : R^q
        c = función condicionante : R^n,R,p -> R^n

    Retorna:

        t : R^{k+1} , t_j = a+j*h para j=0,1,...,k
        w : R^{n,k+1} , w_ij = x_i(t_j) para i=0,1,...,n-1 y j=0,1,...,k

    donde a+k*dt = b.
    """
    assert k>0
    n = len(xa)
    h = (b-a)/k
    w = np.zeros((n,k+1)) # Produce un array con forma y tipo especificada con los parametros,
                          # lleno de ceros. la forma puede ser espcificada con un entero o tupla (n,k+1)
    t = np.zeros(k+1)
    w[:,0] = xa           # actualiza la posicion inicial (columna de indice 0) de las variables con los valores
                          # de las condiciones iniciales
    t[0] = a              # actualiza la posicion cero con el valor del tiempo inicial

    for j in range(k):    #Aca se produce la iteración en j

        t[j+1] = t[j] + h                # iteracion tiempo
        w[:,j+1] = m(f,w[:,j],t[j],h,p)  # iteracion de w
        w[:,j+1] = c(w[:,j+1],t[j+1],p)  # condicion sobre w

    return t,w

# %% [markdown]
# ## Ejercicio 2)
#
# Considere el sistema de Ecuaciones Diferenciales Ordinarias de Lorenz
#
# \begin{eqnarray}
# \frac{dx}{dt} & = & s(y-x) \\
# \frac{dy}{dt} & = & rx-y-xz \\
# \frac{dz}{dt} & = & xy-bz
# \end{eqnarray}
#
# Sea $p=(s,r,b)$ el vector de parámetros.
#
# **1)**
# Usando el método de Runge-Kutta de orden 4, resuelva la ODE para las siguientes elecciones de las condiciones iniciales, de los parámetros y del intervalo de tiempo de integración:
#
# &nbsp; &nbsp; **i)** $(x(0),y(0),z(0))=(1,0.5,0.1)$, $p=(10,0.5,8/3)$ y $t\in [0,10]$.
#
# &nbsp; &nbsp; **ii)** $(x(0),y(0),z(0))=(1,0.5,0.1)$, $p=(10,10,8/3)$ y $t\in [0,20]$.
#
# &nbsp; &nbsp; **iii)** $(x(0),y(0),z(0))=(1,0.5,0.1)$, $p=(10,28,8/3)$ y $t\in [0,50]$
#
# **2)** Para cada caso calculado en el inciso **1)**, grafique, en un mismo gráfico, las curvas en función del tiempo $x(t)$ vs $t$, $y(t)$ vs $t$ y $z(t)$ vs $t$.
#
# **3)**
# Para cada caso calculado en el inciso **1)**, grafique paramétricamente en función del tiempo, y en 3 dimensiones, el vector que describe la trayectoria de la solución, i.e. grafique $(x(t),y(t),z(t))$ vs $t$.

# %%
# 2.1)
def f_lorenz(x, t, p):
    s, r, b = p
    dxdt = s*(x[1] - x[0])
    dydt = r*x[0] - x[1] - x[0]*x[2]
    dzdt = x[0]*x[1] - b*x[2]
    return np.array([dxdt, dydt, dzdt])

# %%
# Parámetros
h = 0.01
s = 10.0
r = 0.5
b = 8.0/3.0
parameters = np.array([s,r,b])

x0 = 1.0
y0 = 0.5
z0 = 0.1
V0 = np.array([x0,y0,z0])

start_time = 0.0
end_time = 10.0
num_steps = int((end_time - start_time) / h)

t, x = integrador_ode(rk4, f_lorenz, V0, start_time, end_time, num_steps, parameters)
x = np.squeeze(x)

# Graficar la solución
plt.figure(figsize=(10, 5))
plt.plot(t, x[0], label='x(t)')
plt.plot(t, x[1], label='y(t)')
plt.plot(t, x[2], label='z(t)')
plt.xlabel('Tiempo (ms)')
plt.ylabel('')
plt.title('Caso i Ecuación de Lorenz')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Parámetros
h = 0.01
s = 10.0
r = 10.0
b = 8.0/3.0
parameters = np.array([s,r,b])

x0 = 1.0
y0 = 0.5
z0 = 0.1
V0 = np.array([x0,y0,z0])

start_time = 0.0
end_time = 20.0
num_steps = int((end_time - start_time) / h)

t, x = integrador_ode(rk4, f_lorenz, V0, start_time, end_time, num_steps, parameters)
x = np.squeeze(x)

# Graficar la solución
plt.figure(figsize=(10, 5))
plt.plot(t, x[0], label='x(t)')
plt.plot(t, x[1], label='y(t)')
plt.plot(t, x[2], label='z(t)')
plt.xlabel('Tiempo (ms)')
plt.ylabel('')
plt.title('Caso ii Ecuación de Lorenz')
plt.grid(True)
plt.legend()
plt.show()

# %%
# Parámetros
h = 0.01
s = 10.0
r = 28.0
b = 8.0/3.0
parameters = np.array([s,r,b])

x0 = 1.0
y0 = 0.5
z0 = 0.1
V0 = np.array([x0,y0,z0])

start_time = 0.0
end_time = 50.0
num_steps = int((end_time - start_time) / h)

t, x = integrador_ode(rk4, f_lorenz, V0, start_time, end_time, num_steps, parameters)
x = np.squeeze(x)

# Graficar la solución
plt.figure(figsize=(10, 5))
plt.plot(t, x[0], label='x(t)')
plt.plot(t, x[1], label='y(t)')
plt.plot(t, x[2], label='z(t)')
plt.xlabel('Tiempo (ms)')
plt.ylabel('')
plt.title('Caso iii Ecuación de Lorenz')
plt.grid(True)
plt.legend()
plt.show()

# %%
#2.3)
import plotly.graph_objects as go
def graficar_3d(x, y, z, titulo):
    fig = go.Figure(data=[go.Scatter3d(x=x, y=y, z=z, 
                                       mode='lines', 
                                       line=dict(color='#1f77b4', width=2))])
    
    fig.update_layout(title=titulo,
                      scene=dict(xaxis_title='x(t)',
                                 yaxis_title='y(t)',
                                 zaxis_title='z(t)'),
                      width=500, height=500)
    
    fig.show()


graficar_3d(x[0], x[1], X[2], 'Caso iii')

# %% [markdown]
# ## Ejercicio 3)
#
# **1)** Repita el caso **1.iii)** del ejercicio **2)**, para $t\in [0,300]$, y eliminando el transiente que se observa antes de "converger" al atractor.
#
# **2)** Identifique los máximos locales de la curva $z(t)$ obtenida en el inciso **1)**, y enumérelos como $z_1,z_2,...,z_i,...,z_n$.
#
# **3)** Grafique $z_{i+1}$ vs $z_i$ para todo $i\in\{1,2,...,n-1\}$.

# %%
# 3.1)
# Parámetros
h = 0.01
s = 10.0
r = 28.0
b = 8.0/3.0
parameters = np.array([s,r,b])

x0 = 1.0
y0 = 0.5
z0 = 0.1
V0 = np.array([x0,y0,z0])

start_time = 0.0
end_time = 300.0
num_steps = int((end_time - start_time) / h)

t, x = integrador_ode(rk4, f_lorenz, V0, start_time, end_time, num_steps, parameters)
x = np.squeeze(x)

t_transiente = 50
t3 = t[t_transiente:]
x3 = x[0][t_transiente:]
y3 = x[1][t_transiente:]
z3 = x[2][t_transiente:]

# Graficar la solución
plt.figure(figsize=(10, 5))
plt.plot(t3, x3, label='x(t)')
plt.plot(t3, y3, label='y(t)')
plt.plot(t3, z3, label='z(t)')
plt.xlabel('Tiempo (ms)')
plt.ylabel('')
plt.title('Caso iii Ecuación de Lorenz')
plt.grid(True)
plt.legend()
plt.show()

# %%
#3.2)
t = t3
z = z3

tmaxs = [t[i] for i in range(1,len(z)-1) if z[i] > z[i-1] and z[i] > z[i+1]]
zmaxs = [z[i] for i in range(1,len(z)-1) if z[i] > z[i-1] and z[i] > z[i+1]]

plt.xlabel("$t$")
plt.ylabel("$z(t)$")

plt.plot(t3, z3, label='z', linestyle="-")
plt.scatter(tmaxs, zmaxs, label='z', linestyle="-", c='r', s=10)
plt.xlim(100, 120)
plt.show()

# %%
#3.3)
plt.xlabel("z(i)")
plt.ylabel("z(i+1)")
plt.scatter(zmaxs[:-1], zmaxs[1:], label='z', linestyle='-')
plt.plot([0,50], [0,50], c='r')
plt.xlim(25, 50)
plt.ylim(25, 50)
plt.show()

# %% [markdown]
# ## Ejercicio 4)
#
# **1)** Con la intención de imitar un set de datos, agregue ruido Gaussiano de varianza $\sigma^2=1$ a la curva $z(t)$ vs $t$ generada en el inciso **1)** del ejercicio **3)**. Llamaremos a esta nueva curva $\tilde{z}(t)$ vs $t$. Grafíquela.
#
# **2)** Utilice algún algoritmo de suavizado de curvas (ver función `savgol_filter` de la librería `scipy.signal`) para suavizar $\tilde{z}(t)$ vs $t$. Llame $\hat{z}(t)$ vs $t$ a la curva suavizada.
#
# **3)** Utilice la curva suavizada del inciso **2)** para identificar los tiempos $\hat{t}_1$,$\hat{t}_2$,...,$\hat{t}_n$ en los cuales ocurre los máximos locales $\hat{z}_1=\hat{z}(\hat{t}_1)$, $\hat{z}_2=\hat{z}(\hat{t}_2)$, ...,$\hat{z}_n=\hat{z}(\hat{t}_n)$ correspondientes.
#
# Calcule además los valores de la curva sin suavizar en dichos tiempos, i.e. calcule $\tilde{z}_1=\tilde{z}(\hat{t_1})$, $\tilde{z}_2=\tilde{z}(\hat{t_2})$, ..., $\tilde{z}_n=\tilde{z}(\hat{t_n})$.
#
# **4)** Grafique la curva suavizada $\tilde{z}(t)$ vs $t$.
#
# Agregue al gráfico los máximos $(\tilde{z}_i,\hat{t}_i)$ con puntos azules, y los máximos $(\hat{z}_i,\hat{t}_i)$ con puntos rojos.
#
# Que observa?
#
# **5)** Grafique $\tilde{z}_{i+1}$ vs $\tilde{z}_i$ para todo $i\in\{1,2,...,n-1\}$.
#
# **6)** Grafique $\hat{z}_{i+1}$ vs $\hat{z}_i$ para todo $i\in\{1,2,...,n-1\}$.
#
# **7)** Comparando los resultados de los incisos **5)** y **6)** con los del gráfico del inciso **3)** del ejercicio **3)**.
#
# Discuta y comente.

# %%
# 4.1)

t = t3
z_tilde = z3 + 1.0*np.random.normal(size=len(z3))

plt.plot(t, z_tilde, label=r'$\tilde{z}(t)$')
plt.xlim(50, 70)
plt.xlabel('Tiempo t')
plt.ylabel(r'$\tilde{z}(t)$')
plt.legend()
plt.show()

# %%
# 4.2)

zsmooth = sgn.savgol_filter(z_tilde, window_length=35, polyorder=3)

plt.plot(t, z_tilde, label=r'$\tilde{z}(t)$')
plt.plot(t, zsmooth, label=r'$\hat{z}(t)$') #, color='tomato')
plt.xlim(50, 70)
plt.xlabel('Tiempo t')
plt.ylabel('$z (t)$')
plt.legend()
plt.show()

# %%
# 4.3)
# Determinamos los tiempos de los valores máximos de la curva suavizada,
# los valores de los datos en dichos tiempos
# y los valores de la curva suavizada en dichos tiempo
zdatamean = z_tilde.mean()

idatamaxs = [i for i in range(1, len(zsmooth)-1) if zsmooth[i] > zsmooth[i-1] and zsmooth[i] > zsmooth[i+1]]
tdatamaxs = [t[i] for i in idatamaxs]
zdatamaxs = [z_tilde[i] for i in idatamaxs]
zsmoothmaxs = [zsmooth[i] for i in idatamaxs]

# %%
# 4.4)
plt.xlabel("$t$")
plt.ylabel("$z(t)$")
plt.plot(t, zsmooth, linestyle='-')
plt.scatter(tdatamaxs, zdatamaxs, label="Máximos curva original", c='b')
plt.scatter(tdatamaxs, zsmoothmaxs, label="Máximos curva suavizada", c='r')
plt.xlim(100, 120)
plt.legend()
plt.show()

# %%
# 4.5)
plt.xlabel("$\\tilde{z}_i$")
plt.ylabel("$\\tilde{z}_{i+1}$")
plt.scatter(zdatamaxs[:-1], zdatamaxs[1:], label='z', linestyle='-')
plt.plot([0,50], [0,50], c='r')
plt.xlim(25, 50)
plt.ylim(25, 50)
plt.show()

# %%
# 4.6)
plt.xlabel("$\\tilde{z}_i$")
plt.ylabel("$\\tilde{z}_{i+1}$")
plt.scatter(zsmoothmaxs[:-1], zsmoothmaxs[1:], label='z', linestyle='-')
plt.plot([0,50], [0,50], c='r')
plt.xlim(25, 50)
plt.ylim(25, 50)
plt.show()

# %%
# 4.7)
